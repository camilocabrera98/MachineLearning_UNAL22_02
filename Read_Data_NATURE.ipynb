# %% [markdown]
# # Import libraries

# %%
import numpy as np 
import pandas as pd 
import datetime
import os
import glob
import scipy as sc
from scipy import signal
import re ## Expresiones regulares
# import sympy as sp

#Librería de graficación
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.ticker as mticker
import matplotlib.cm as cm
import matplotlib.dates as mdates
import matplotlib as mpl
from matplotlib.offsetbox import AnchoredText
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.gridspec as gridspec
import matplotlib.pylab as pl

# Personalizar graficas
plt.style.use('default')
mpl.rcParams['xtick.labelsize']=14
mpl.rcParams['ytick.labelsize']=14
mpl.rcParams['font.sans-serif'] = "Century Gothic"
mpl.rcParams['font.family'] = "Century Gothic"
mpl.rcParams['font.weight'] = 'normal'

# %%
with np.load('/content/drive/Othercomputers/Mi PC/Maestria_Sem_II/MachineLearning/Data_NATURE_Nonlinear_wave_evolution_with_data_driven_breaking/\
Measurements/HPPW_f0_1p30_ak_0p14_sbFrac_0p05_unb_0p00_psi_1p00_Omegam_1p00_eta.npz') as data:
    etaMat = data["etaMat"]
    envMat = data["envMat"]
    etaMatSpec = data["etaMatSpec"]
    freqAx = data["freqAx"]
    t = data["t"]
    pos_wg = data["pos_wg"]

# %%
print(etaMat.shape)
print(envMat.shape)
print(etaMatSpec.shape)
print(freqAx.shape)
print(t.shape)
print(pos_wg.shape)
# Out:
# (15, 23266)
# (15, 23266)
# (15, 16384)
# (16384,)
# (23266,)
# (15,)

# %%
print(t)
print(pos_wg)
# Out:
# [0.00000e+00 2.50000e-03 5.00000e-03 ... 5.81575e+01 5.81600e+01
#  5.81625e+01]
# [ 3.79  6.64  8.82 11.63 13.73 16.11 18.78 21.83 24.53 26.96 29.1  31.1
#   8.82 16.11 24.53]

# %%
etaMat[2,:]
# Out:
# array([ 0.        ,  0.00206035,  0.0082601 , ..., -0.00572023,
#        -0.00133895, -0.        ])

# %%
etaMat[12,:]
# Out:
# array([ 0.        ,  0.00369739,  0.01501101, ..., -0.00883266,
#        -0.00202808, -0.        ])

# %%
plt.plot(etaMat[2,:])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Century Gothic'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(etaMat[12,:])

# %%
plt.plot(freqAx,etaMatSpec[2,:])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
